# %% [markdown]
# ## All python Imports

# %%
# Normal Sci. Comp. Imports
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
# create random number generator for later/throughout
rng = np.random.default_rng(seed=120695)
# Load the keras data set module:
from tensorflow.keras.datasets import fashion_mnist
# import keras stuff
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Function for Prediction Stats

# %%
def mis_cls_stats(prds:np.array, truth:np.array):
    """ Identify some statistics about the misclassifications like what was mis classifided 
        how many times it was misclassifed, what was most often classified for incorrectly
        for it, etc.
        prds = predictions
        truth = true labels
    """
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    # get number of sample/test
    M = truth.shape[0]
    # number of correct and wrong predictions
    num_r, num_w = np.sum(prds==truth), np.count_nonzero(prds-truth)
    print(f"The model gave {num_r} correct and {num_w} wrong predictions giving")
    print(f"an accuracy rate of {(num_r)/M} and an error rate of {(num_w)/M} \n")
    # first get the indices of the predictions matrix that were incorrect
    idx = np.nonzero(prds!=truth)[0]
    # now get all the labels that were miss classified and how many times so (counts_wrong)
    lbls, counts_w = np.unique(prds[idx], return_counts=True)
    # also get the correct number of labels and simplify the classes list
    counts_c = np.empty_like(counts_w)
    usd_cls = []
    for i in range(len(counts_w)):
        counts_c[i] = np.sum(truth == lbls[i])
        usd_cls.append(class_names[lbls[i]])
    # determine the individual class accuracies 
    cls_acc = 100*(1 - counts_w/counts_c)
    for i, l in enumerate(lbls):
        print(f"Label/class {class_names[l]} was miss labeled/classified {counts_w[i]} times")
        print(f"So approximately {100 *counts_w[i]/num_w:.2f}% of the misslabels were for {class_names[l]}")
        print(f"the accuracy rate for the {class_names[l]} alone was {cls_acc[i]:.2f}%\n")
        
    # plot horizonal bar char displaying misclassification per class
    fig1, ax1 = plt.subplots(figsize=(9,6))
    y_pos = np.arange(len(lbls))
    ax1.barh(y_pos, counts_w, align='center')
    ax1.set_yticks(y_pos, labels=usd_cls)
    ax1.set_xlabel('Miss Classifications')
    ax1.set_title(f'Num. Misclassifications For Model - Total = {num_w}')
    # Now create a verical bar chart for each class showing what was the miss classifications 
    # maximum of 20 sub figures and minimum of 2 (realistically going to have some misclassif.)
    num_cols = 2
    num_images = 2*len(lbls)
    num_rows = int(np.ceil(num_images/4))
    # plots is an example image of a label/class then its misclassification charts of what was 
    # predicted instead of it and some other things. Us two images per class and we want for 
    # images per row. 
    fig, ax = plt.subplots(num_rows, 2*num_cols, figsize=(2.5*2*num_cols, 2*num_rows))
    # tmp_img = np.empty((28,28), dtype=float)
    for i, l in enumerate(lbls):
        i_r, i_c = int(i/2), 0
        if i%2==1:
            i_c = 2
        # first display an image of the label
        jdx = np.nonzero(truth == l)[0][0]
        ax[i_r][i_c].set_xticks([])
        ax[i_r][i_c].set_yticks([])
        ax[i_r][i_c].imshow(x_test[jdx].reshape(28,28), cmap='gray')
        ax[i_r][i_c].set_xlabel(f"{class_names[l]}, {cls_acc[i]:.2f}% Acc.", fontsize=9)
        # now display bar chart of what was predicted instead
        ids = np.nonzero(prds[idx]==l)
        gues, g_counts = np.unique(truth[idx[ids]], return_counts=True)
        ax[i_r][i_c+1].bar(range(len(gues)), g_counts, align='center', color='red')
        ax[i_r][i_c+1].set_ylabel('Amount', fontsize=9)
        ax[i_r][i_c+1].set_xlabel('Wrong Predictions', fontsize=9)
        g_lbl = []
        for i in range(len(gues)):
            g_lbl.append(class_names[gues[i]])
        ax[i_r][i_c+1].set_xticks(range(len(gues)), g_lbl, fontsize=6.5, rotation=65)
        ax[i_r][i_c+1].set_title(f"{class_names[l]}, Misclassifications", fontsize=9)
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Data importing and then Normalization, etc

# %%
# with fashion mnist model data is already partitioned into training and validation
(X, Y), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_valid = X[:48000], X[48000:]
y_train, y_valid = Y[:48000], Y[48000:]
# Reshape and Normalize the data
x_train = x_train.reshape(-1, 784)
x_valid = x_valid.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)
norm_tr = x_train / 255
norm_va = x_valid / 255
norm_tst = x_test / 255
# Categorically encode the data (one-hot encoding)
num_categories = len(np.unique(y_train))
y_tr_encoded = keras.utils.to_categorical(y_train, num_categories)
y_va_encoded = keras.utils.to_categorical(y_valid, num_categories)
y_tst_encoded = keras.utils.to_categorical(y_test, num_categories)

# %% [markdown]
# ## Data matrix and looping Variables

# %%
nodes= 2**np.arange(6, 12)
g_data = np.empty(shape=(6,2))
out_data = np.empty(shape=(12,10))
opt = keras.optimizers.Adam(learning_rate=0.001)

# %% [markdown]
# ## Loop to Create and Train the Model with 2 hidden layers only - Save data each pass

# %%
for i in range(6):
    # create a new model in each time through the loop
    model2 = Sequential() 
    # input layer and first hidden layer
    model2.add(Dense(units=nodes[i], activation='relu', input_shape=(784,)))
    # second hidden layer
    model2.add(Dense(units=nodes[i], activation='relu',))
    # output layer
    model2.add(Dense(units=10, activation='softmax'))
    # now compile the models with the the correct loss, metrcs and optimzation method
    model2.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)
    history2 = model2.fit(
        x=norm_tr, y=y_tr_encoded, batch_size=32, epochs=10, verbose=0, validation_data=(norm_va, y_va_encoded)
    )
    # now trained save the validation and training accuracy results
    out_data[2*i] = history2.history['accuracy']
    out_data[2*i+1] = history2.history['val_accuracy']
    g_data[i, 0], g_data[i, 1] = history2.history['accuracy'][-1], history2.history['val_accuracy'][-1]
    if i != 5:
        del model2
    
out_data = out_data.T
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5353 - accuracy: 0.8112 - val_loss: 0.4288 - val_accuracy: 0.8454
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3980 - accuracy: 0.8560 - val_loss: 0.4068 - val_accuracy: 0.8522
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3566 - accuracy: 0.8692 - val_loss: 0.3663 - val_accuracy: 0.8677
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3289 - accuracy: 0.8765 - val_loss: 0.3717 - val_accuracy: 0.8698
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3127 - accuracy: 0.8842 - val_loss: 0.3491 - val_accuracy: 0.8725
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2962 - accuracy: 0.8899 - val_loss: 0.3348 - val_accuracy: 0.8832
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2840 - accuracy: 0.8937 - val_loss: 0.3428 - val_accuracy: 0.8755
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2719 - accuracy: 0.8984 - val_loss: 0.3286 - val_accuracy: 0.8815
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2631 - accuracy: 0.9018 - val_loss: 0.3268 - val_accuracy: 0.8827
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2538 - accuracy: 0.9051 - val_loss: 0.3332 - val_accuracy: 0.8808
# Epoch 1/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.4681 - accuracy: 0.8300 - val_loss: 0.3814 - val_accuracy: 0.8646
# Epoch 2/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3553 - accuracy: 0.8700 - val_loss: 0.3550 - val_accuracy: 0.8705
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3225 - accuracy: 0.8801 - val_loss: 0.3886 - val_accuracy: 0.8572
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3008 - accuracy: 0.8881 - val_loss: 0.3656 - val_accuracy: 0.8715
# Epoch 5/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2849 - accuracy: 0.8930 - val_loss: 0.3232 - val_accuracy: 0.8838
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2712 - accuracy: 0.8976 - val_loss: 0.3169 - val_accuracy: 0.8842
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2583 - accuracy: 0.9032 - val_loss: 0.3399 - val_accuracy: 0.8802
# Epoch 8/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2492 - accuracy: 0.9059 - val_loss: 0.3288 - val_accuracy: 0.8858
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2382 - accuracy: 0.9113 - val_loss: 0.3279 - val_accuracy: 0.8834
# Epoch 10/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2331 - accuracy: 0.9119 - val_loss: 0.3348 - val_accuracy: 0.8828
# Epoch 1/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4616 - accuracy: 0.8334 - val_loss: 0.3693 - val_accuracy: 0.8673
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3484 - accuracy: 0.8721 - val_loss: 0.3567 - val_accuracy: 0.8655
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3148 - accuracy: 0.8821 - val_loss: 0.3870 - val_accuracy: 0.8624
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2913 - accuracy: 0.8916 - val_loss: 0.3415 - val_accuracy: 0.8779
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2758 - accuracy: 0.8965 - val_loss: 0.3335 - val_accuracy: 0.8817
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2603 - accuracy: 0.9013 - val_loss: 0.3221 - val_accuracy: 0.8859
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2496 - accuracy: 0.9051 - val_loss: 0.3514 - val_accuracy: 0.8742
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2388 - accuracy: 0.9106 - val_loss: 0.3233 - val_accuracy: 0.8863
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2304 - accuracy: 0.9130 - val_loss: 0.3090 - val_accuracy: 0.8917
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2194 - accuracy: 0.9157 - val_loss: 0.3549 - val_accuracy: 0.8777
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4739 - accuracy: 0.8276 - val_loss: 0.4122 - val_accuracy: 0.8462
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3517 - accuracy: 0.8702 - val_loss: 0.3539 - val_accuracy: 0.8737
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3198 - accuracy: 0.8812 - val_loss: 0.3397 - val_accuracy: 0.8788
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2978 - accuracy: 0.8879 - val_loss: 0.3336 - val_accuracy: 0.8802
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2796 - accuracy: 0.8938 - val_loss: 0.3341 - val_accuracy: 0.8832
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2681 - accuracy: 0.8992 - val_loss: 0.3402 - val_accuracy: 0.8779
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2575 - accuracy: 0.9030 - val_loss: 0.3227 - val_accuracy: 0.8859
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2433 - accuracy: 0.9073 - val_loss: 0.3403 - val_accuracy: 0.8838
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2359 - accuracy: 0.9099 - val_loss: 0.3277 - val_accuracy: 0.8870
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2260 - accuracy: 0.9135 - val_loss: 0.3394 - val_accuracy: 0.8880
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4803 - accuracy: 0.8284 - val_loss: 0.3957 - val_accuracy: 0.8578
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3532 - accuracy: 0.8696 - val_loss: 0.3553 - val_accuracy: 0.8682
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3222 - accuracy: 0.8812 - val_loss: 0.3292 - val_accuracy: 0.8823
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3003 - accuracy: 0.8863 - val_loss: 0.3330 - val_accuracy: 0.8777
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2815 - accuracy: 0.8932 - val_loss: 0.3483 - val_accuracy: 0.8730
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2706 - accuracy: 0.8982 - val_loss: 0.3520 - val_accuracy: 0.8759
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2563 - accuracy: 0.9032 - val_loss: 0.3375 - val_accuracy: 0.8808
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2476 - accuracy: 0.9053 - val_loss: 0.3474 - val_accuracy: 0.8798
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2375 - accuracy: 0.9103 - val_loss: 0.3432 - val_accuracy: 0.8855
# Epoch 10/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2275 - accuracy: 0.9141 - val_loss: 0.3386 - val_accuracy: 0.8841
# Epoch 1/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.5046 - accuracy: 0.8233 - val_loss: 0.4015 - val_accuracy: 0.8563
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3652 - accuracy: 0.8665 - val_loss: 0.3728 - val_accuracy: 0.8650
# Epoch 3/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3332 - accuracy: 0.8769 - val_loss: 0.3590 - val_accuracy: 0.8670
# Epoch 4/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3137 - accuracy: 0.8839 - val_loss: 0.3662 - val_accuracy: 0.8712
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2956 - accuracy: 0.8892 - val_loss: 0.3536 - val_accuracy: 0.8751
# Epoch 6/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2859 - accuracy: 0.8925 - val_loss: 0.3305 - val_accuracy: 0.8780
# Epoch 7/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2723 - accuracy: 0.8966 - val_loss: 0.3808 - val_accuracy: 0.8658
# Epoch 8/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2657 - accuracy: 0.8989 - val_loss: 0.3579 - val_accuracy: 0.8752
# Epoch 9/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2585 - accuracy: 0.9017 - val_loss: 0.3352 - val_accuracy: 0.8813
# Epoch 10/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2460 - accuracy: 0.9066 - val_loss: 0.3502 - val_accuracy: 0.8832

# %% [markdown]
# ## Save the training and validation accuracies over each epoch to txt file

# %%
np.savetxt(fname='TF_datasets/FFNN_VarNodes_Acc_data.txt', X=out_data, header='(2) Tr Acc, - (2) Val Acc. - (3) Tr Acc. - (3) Val Acc. - ...')

# %% [markdown]
# ## Make some predictions

# %%
p2 = model2.predict(x=norm_tst)
preds2 = np.argmax(p2, axis=1)
mis_cls_stats(preds2, y_test)
# Out:
# The model gave 8788 correct and 1212 wrong predictions giving
# an accuracy rate of 0.8788 and an error rate of 0.1212
#
# Label/class T-shirt/top was miss labeled/classified 117 times
# So approximately 9.65% of the misslabels were for T-shirt/top
# the accuracy rate for the T-shirt/top alone was 88.30%
#
# Label/class Trouser was miss labeled/classified 12 times
# So approximately 0.99% of the misslabels were for Trouser
# the accuracy rate for the Trouser alone was 98.80%
#
# Label/class Pullover was miss labeled/classified 252 times
# So approximately 20.79% of the misslabels were for Pullover
# the accuracy rate for the Pullover alone was 74.80%
#
# Label/class Dress was miss labeled/classified 157 times
# So approximately 12.95% of the misslabels were for Dress
# the accuracy rate for the Dress alone was 84.30%
#
# Label/class Coat was miss labeled/classified 157 times
# So approximately 12.95% of the misslabels were for Coat
# the accuracy rate for the Coat alone was 84.30%
#
# Label/class Sandal was miss labeled/classified 30 times
# So approximately 2.48% of the misslabels were for Sandal
# the accuracy rate for the Sandal alone was 97.00%
#
# Label/class Shirt was miss labeled/classified 354 times
# So approximately 29.21% of the misslabels were for Shirt
# the accuracy rate for the Shirt alone was 64.60%
#
# Label/class Sneaker was miss labeled/classified 57 times
# So approximately 4.70% of the misslabels were for Sneaker
# the accuracy rate for the Sneaker alone was 94.30%
#
# Label/class Bag was miss labeled/classified 32 times
# So approximately 2.64% of the misslabels were for Bag
# the accuracy rate for the Bag alone was 96.80%
#
# Label/class Ankle boot was miss labeled/classified 44 times
# So approximately 3.63% of the misslabels were for Ankle boot
# the accuracy rate for the Ankle boot alone was 95.60%
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Extra:
# A separate notebook takes the data saved above to create a plot of the training and validation accuracy from one epoch to the next but if you want to display it here and save it to the current working directory copy and past the following lines of python code into a code cell and run it.
# ```Python
# fig = plt.figure()
# plt.plot(nodes, g_data[:, 0]*100, 'k.--', nodes, g_data[:, 1]*100, 'b.--', markersize=16)
# plt.xlabel('Num Nodes', fontsize=16)
# plt.ylabel('% Accuracy', fontsize=16)
# plt.legend(['Train', 'Validation'], fontsize=16)
# plt.show()
# plt.savefig(fname='Vary_Nodes.png', format='png')
# ```

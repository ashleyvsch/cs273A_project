# %% [markdown]
# ## All python Imports

# %%
# Normal Sci. Comp. Imports
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
# create random number generator for later/throughout
rng = np.random.default_rng(seed=120695)
# Load the keras data set module:
from tensorflow.keras.datasets import fashion_mnist
# import keras stuff
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Data importing and then Normalization, etc

# %%
# with fashion mnist model data is already partitioned into training and validation
(X, Y), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_valid = X[:48000], X[48000:]
y_train, y_valid = Y[:48000], Y[48000:]
# Reshape and Normalize the data
x_train = x_train.reshape(-1, 784)
x_valid = x_valid.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)
norm_tr = x_train / 255
norm_va = x_valid / 255
norm_tst = x_test / 255
# Categorically encode the data (one-hot encoding)
num_categories = len(np.unique(y_train))
y_tr_encoded = keras.utils.to_categorical(y_train, num_categories)
y_va_encoded = keras.utils.to_categorical(y_valid, num_categories)
y_tst_encoded = keras.utils.to_categorical(y_test, num_categories)

# %% [markdown]
# ## Create the Model with 2 hidden layers only

# %%
model2 = Sequential() 
# input layer and first hidden layer
model2.add(Dense(units=256, activation='relu', input_shape=(784,)))
# second hidden layer
model2.add(Dense(units=256, activation='relu',))
# output layer
model2.add(Dense(units=10, activation='softmax'))
opt = keras.optimizers.Adam(learning_rate=0.001)
# now compile the models with the the correct loss, metrcs and optimzation method
model2.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Create the Model with 3 hidden layers

# %%
model3 = Sequential()
model3.add(Dense(units=256, activation='relu', input_shape=(784,)))
# second hidden layer
model3.add(Dense(units=256, activation='relu',))
# third hidden layer
model3.add(Dense(units=256, activation='relu',))
# output layer
model3.add(Dense(units=10, activation='softmax'))
# now compile the models with the the correct loss, metrcs and optimzation method
model3.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)

# %% [markdown]
# ## Create the Model with 4 hidden layers

# %%
model4 = Sequential()
model4.add(Dense(units=256, activation='relu', input_shape=(784,)))
# second hidden layer
model4.add(Dense(units=256, activation='relu',))
# third hidden layer
model4.add(Dense(units=256, activation='relu',))
# fourth hidden layer
model4.add(Dense(units=256, activation='relu',))
# output layer
model4.add(Dense(units=10, activation='softmax'))
# now compile the models with the the correct loss, metrcs and optimzation method
model4.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)

# %% [markdown]
# ## Create the Model with 5 hidden layers

# %%
model5 = Sequential()
model5.add(Dense(units=256, activation='relu', input_shape=(784,)))
model5.add(Dense(units=256, activation='relu',))# second hidden layer
model5.add(Dense(units=256, activation='relu',))# third hidden layer
model5.add(Dense(units=256, activation='relu',))# fourth hidden layer
model5.add(Dense(units=256, activation='relu',))# fifth hidden layer
# output layer
model5.add(Dense(units=10, activation='softmax'))
# now compile the models with the the correct loss, metrcs and optimzation method
model5.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)

# %% [markdown]
# ## Create the Model with 6 hidden layers

# %%
model6 = Sequential()
model6.add(Dense(units=256, activation='relu', input_shape=(784,)))
model6.add(Dense(units=256, activation='relu',))# second hidden layer
model6.add(Dense(units=256, activation='relu',))# third hidden layer
model6.add(Dense(units=256, activation='relu',))# fourth hidden layer
model6.add(Dense(units=256, activation='relu',))# fifth hidden layer
model6.add(Dense(units=256, activation='relu',))# sixth hidden layer
# output layer
model6.add(Dense(units=10, activation='softmax'))
# now compile the models with the the correct loss, metrcs and optimzation method
model6.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)

# %% [markdown]
# ## Train the models

# %%
history2 = model2.fit(
    x=norm_tr, y=y_tr_encoded, batch_size=32, epochs=10, verbose=1, validation_data=(norm_va, y_va_encoded)
)
history3 = model3.fit(
    x=norm_tr, y=y_tr_encoded, batch_size=32, epochs=10, verbose=1, validation_data=(norm_va, y_va_encoded)
)
history4 = model4.fit(
    x=norm_tr, y=y_tr_encoded, batch_size=32, epochs=10, verbose=1, validation_data=(norm_va, y_va_encoded)
)
history5 = model5.fit(
    x=norm_tr, y=y_tr_encoded, batch_size=32, epochs=10, verbose=1, validation_data=(norm_va, y_va_encoded)
)
history6 = model6.fit(
    x=norm_tr, y=y_tr_encoded, batch_size=32, epochs=10, verbose=1, validation_data=(norm_va, y_va_encoded)
)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4912 - accuracy: 0.8222 - val_loss: 0.4180 - val_accuracy: 0.8461
# Epoch 2/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3683 - accuracy: 0.8652 - val_loss: 0.3651 - val_accuracy: 0.8658
# Epoch 3/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3289 - accuracy: 0.8792 - val_loss: 0.3378 - val_accuracy: 0.8762
# Epoch 4/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3034 - accuracy: 0.8865 - val_loss: 0.3594 - val_accuracy: 0.8761
# Epoch 5/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2888 - accuracy: 0.8925 - val_loss: 0.3456 - val_accuracy: 0.8743
# Epoch 6/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.2717 - accuracy: 0.8970 - val_loss: 0.3275 - val_accuracy: 0.8853
# Epoch 7/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2580 - accuracy: 0.9017 - val_loss: 0.3350 - val_accuracy: 0.8843
# Epoch 8/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2498 - accuracy: 0.9059 - val_loss: 0.3323 - val_accuracy: 0.8852
# Epoch 9/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2361 - accuracy: 0.9109 - val_loss: 0.3250 - val_accuracy: 0.8886
# Epoch 10/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2244 - accuracy: 0.9139 - val_loss: 0.3538 - val_accuracy: 0.8793
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.4825 - accuracy: 0.8224 - val_loss: 0.4028 - val_accuracy: 0.8556
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3573 - accuracy: 0.8668 - val_loss: 0.3645 - val_accuracy: 0.8677
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3237 - accuracy: 0.8785 - val_loss: 0.3326 - val_accuracy: 0.8787
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3016 - accuracy: 0.8872 - val_loss: 0.3497 - val_accuracy: 0.8743
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2847 - accuracy: 0.8941 - val_loss: 0.3747 - val_accuracy: 0.8726
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2722 - accuracy: 0.8978 - val_loss: 0.3276 - val_accuracy: 0.8856
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2601 - accuracy: 0.9021 - val_loss: 0.3306 - val_accuracy: 0.8856
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2494 - accuracy: 0.9048 - val_loss: 0.3451 - val_accuracy: 0.8792
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2385 - accuracy: 0.9091 - val_loss: 0.3420 - val_accuracy: 0.8821
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2319 - accuracy: 0.9110 - val_loss: 0.3345 - val_accuracy: 0.8891
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5069 - accuracy: 0.8135 - val_loss: 0.4093 - val_accuracy: 0.8528
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3684 - accuracy: 0.8643 - val_loss: 0.3729 - val_accuracy: 0.8669
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3366 - accuracy: 0.8756 - val_loss: 0.3567 - val_accuracy: 0.8707
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3136 - accuracy: 0.8832 - val_loss: 0.3341 - val_accuracy: 0.8763
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2978 - accuracy: 0.8896 - val_loss: 0.3552 - val_accuracy: 0.8753
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2865 - accuracy: 0.8935 - val_loss: 0.3547 - val_accuracy: 0.8744
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2718 - accuracy: 0.8991 - val_loss: 0.3551 - val_accuracy: 0.8761
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2634 - accuracy: 0.9024 - val_loss: 0.3250 - val_accuracy: 0.8808
# Epoch 9/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2514 - accuracy: 0.9063 - val_loss: 0.3556 - val_accuracy: 0.8780
# Epoch 10/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2470 - accuracy: 0.9070 - val_loss: 0.3380 - val_accuracy: 0.8822
# Epoch 1/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.5397 - accuracy: 0.7987 - val_loss: 0.4239 - val_accuracy: 0.8443
# Epoch 2/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3852 - accuracy: 0.8583 - val_loss: 0.3892 - val_accuracy: 0.8608
# Epoch 3/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3468 - accuracy: 0.8719 - val_loss: 0.3592 - val_accuracy: 0.8700
# Epoch 4/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3213 - accuracy: 0.8817 - val_loss: 0.3394 - val_accuracy: 0.8759
# Epoch 5/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3055 - accuracy: 0.8881 - val_loss: 0.3483 - val_accuracy: 0.8757
# Epoch 6/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2898 - accuracy: 0.8919 - val_loss: 0.3452 - val_accuracy: 0.8809
# Epoch 7/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2791 - accuracy: 0.8963 - val_loss: 0.3446 - val_accuracy: 0.8777
# Epoch 8/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2684 - accuracy: 0.8999 - val_loss: 0.3402 - val_accuracy: 0.8809
# Epoch 9/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2622 - accuracy: 0.9020 - val_loss: 0.3422 - val_accuracy: 0.8773
# Epoch 10/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2537 - accuracy: 0.9047 - val_loss: 0.3484 - val_accuracy: 0.8839
# Epoch 1/10
# 1500/1500 [==============================] - 9s 5ms/step - loss: 0.5653 - accuracy: 0.7874 - val_loss: 0.4425 - val_accuracy: 0.8425
# Epoch 2/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.4011 - accuracy: 0.8533 - val_loss: 0.3745 - val_accuracy: 0.8634
# Epoch 3/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3585 - accuracy: 0.8694 - val_loss: 0.3720 - val_accuracy: 0.8692
# Epoch 4/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3367 - accuracy: 0.8763 - val_loss: 0.3429 - val_accuracy: 0.8765
# Epoch 5/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3213 - accuracy: 0.8805 - val_loss: 0.3519 - val_accuracy: 0.8740
# Epoch 6/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.3079 - accuracy: 0.8874 - val_loss: 0.3631 - val_accuracy: 0.8714
# Epoch 7/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2941 - accuracy: 0.8913 - val_loss: 0.3751 - val_accuracy: 0.8694
# Epoch 8/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2867 - accuracy: 0.8932 - val_loss: 0.3379 - val_accuracy: 0.8748
# Epoch 9/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2795 - accuracy: 0.8961 - val_loss: 0.3372 - val_accuracy: 0.8836
# Epoch 10/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2718 - accuracy: 0.9006 - val_loss: 0.3552 - val_accuracy: 0.8750

# %% [markdown]
# ## Save training data to file and then get predction data and accuracy

# %%
out_data = np.empty(shape=(10, 10))
g_data = np.empty(shape=(5, 2))
g_data[0,0], g_data[0, 1] = history2.history['accuracy'][-1], history2.history['val_accuracy'][-1]
g_data[1,0], g_data[1, 1] = history3.history['accuracy'][-1], history3.history['val_accuracy'][-1]
g_data[2,0], g_data[2, 1] = history4.history['accuracy'][-1], history4.history['val_accuracy'][-1]
g_data[3,0], g_data[3, 1] = history5.history['accuracy'][-1], history5.history['val_accuracy'][-1]
g_data[4,0], g_data[4, 1] = history6.history['accuracy'][-1], history6.history['val_accuracy'][-1]

# %%
out_data[0] = history2.history['accuracy']
out_data[1] = history2.history['val_accuracy']
out_data[2] = history3.history['accuracy']
out_data[3] = history3.history['val_accuracy']
out_data[4] = history4.history['accuracy']
out_data[5] = history4.history['val_accuracy']
out_data[6] = history5.history['accuracy']
out_data[7] = history5.history['val_accuracy']
out_data[8] = history6.history['accuracy']
out_data[9] = history6.history['val_accuracy']
out_data = out_data.T
np.savetxt(fname='TF_datasets/FFNN_VarLays_Acc_data.txt', X=out_data, header='(2) Tr Acc, - (2) Val Acc. - (3) Tr Acc. - (3) Val Acc. - ...')

# %%
p2 = model2.predict(x=norm_tst)
preds2 = np.argmax(p2, axis=1)
p3 = model3.predict(x=norm_tst)
preds3 = np.argmax(p3, axis=1)
p4 = model4.predict(x=norm_tst)
preds4 = np.argmax(p4, axis=1)
p5 = model5.predict(x=norm_tst)
preds5 = np.argmax(p5, axis=1)
p6 = model6.predict(x=norm_tst)
preds6 = np.argmax(p6, axis=1)
def mis_cls_stats(prds:np.array, truth:np.array):
    """ Identify some statistics about the misclassifications like what was mis classifided 
        how many times it was misclassifed, what was most often classified for incorrectly
        for it, etc.
        prds = predictions
        truth = true labels
    """
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    # get number of sample/test
    M = truth.shape[0]
    # number of correct and wrong predictions
    num_r, num_w = np.sum(prds==truth), np.count_nonzero(prds-truth)
    print(f"The model gave {num_r} correct and {num_w} wrong predictions giving")
    print(f"an accuracy rate of {(num_r)/M} and an error rate of {(num_w)/M} \n")
    # first get the indices of the predictions matrix that were incorrect
    idx = np.nonzero(prds!=truth)[0]
    # now get all the labels that were miss classified and how many times so (counts_wrong)
    lbls, counts_w = np.unique(prds[idx], return_counts=True)
    # also get the correct number of labels and simplify the classes list
    counts_c = np.empty_like(counts_w)
    usd_cls = []
    for i in range(len(counts_w)):
        counts_c[i] = np.sum(truth == lbls[i])
        usd_cls.append(class_names[lbls[i]])
    # determine the individual class accuracies 
    cls_acc = 100*(1 - counts_w/counts_c)
    for i, l in enumerate(lbls):
        print(f"Label/class {class_names[l]} was miss labeled/classified {counts_w[i]} times")
        print(f"So approximately {100 *counts_w[i]/num_w:.2f}% of the misslabels were for {class_names[l]}")
        print(f"the accuracy rate for the {class_names[l]} alone was {cls_acc[i]:.2f}%\n")
        
    # plot horizonal bar char displaying misclassification per class
    fig1, ax1 = plt.subplots(figsize=(9,6))
    y_pos = np.arange(len(lbls))
    ax1.barh(y_pos, counts_w, align='center')
    ax1.set_yticks(y_pos, labels=usd_cls)
    ax1.set_xlabel('Miss Classifications')
    ax1.set_title(f'Num. Misclassifications For Model - Total = {num_w}')
    # Now create a verical bar chart for each class showing what was the miss classifications 
    # maximum of 20 sub figures and minimum of 2 (realistically going to have some misclassif.)
    num_cols = 2
    num_images = 2*len(lbls)
    num_rows = int(np.ceil(num_images/4))
    # plots is an example image of a label/class then its misclassification charts of what was 
    # predicted instead of it and some other things. Us two images per class and we want for 
    # images per row. 
    fig, ax = plt.subplots(num_rows, 2*num_cols, figsize=(2.5*2*num_cols, 2*num_rows))
    # tmp_img = np.empty((28,28), dtype=float)
    for i, l in enumerate(lbls):
        i_r, i_c = int(i/2), 0
        if i%2==1:
            i_c = 2
        # first display an image of the label
        jdx = np.nonzero(truth == l)[0][0]
        ax[i_r][i_c].set_xticks([])
        ax[i_r][i_c].set_yticks([])
        ax[i_r][i_c].imshow(x_test[jdx].reshape(28,28), cmap='gray')
        ax[i_r][i_c].set_xlabel(f"{class_names[l]}, {cls_acc[i]:.2f}% Acc.", fontsize=9)
        # now display bar chart of what was predicted instead
        ids = np.nonzero(prds[idx]==l)
        gues, g_counts = np.unique(truth[idx[ids]], return_counts=True)
        ax[i_r][i_c+1].bar(range(len(gues)), g_counts, align='center', color='red')
        ax[i_r][i_c+1].set_ylabel('Amount', fontsize=9)
        ax[i_r][i_c+1].set_xlabel('Wrong Predictions', fontsize=9)
        g_lbl = []
        for i in range(len(gues)):
            g_lbl.append(class_names[gues[i]])
        ax[i_r][i_c+1].set_xticks(range(len(gues)), g_lbl, fontsize=6.5, rotation=65)
        ax[i_r][i_c+1].set_title(f"{class_names[l]}, Misclassifications", fontsize=9)
        
    plt.tight_layout()
    plt.show()

# %%
mis_cls_stats(preds2, y_test)
# Out:
# The model gave 8736 correct and 1264 wrong predictions giving
# an accuracy rate of 0.8736 and an error rate of 0.1264
#
# Label/class T-shirt/top was miss labeled/classified 151 times
# So approximately 11.95% of the misslabels were for T-shirt/top
# the accuracy rate for the T-shirt/top alone was 84.90%
#
# Label/class Trouser was miss labeled/classified 9 times
# So approximately 0.71% of the misslabels were for Trouser
# the accuracy rate for the Trouser alone was 99.10%
#
# Label/class Pullover was miss labeled/classified 316 times
# So approximately 25.00% of the misslabels were for Pullover
# the accuracy rate for the Pullover alone was 68.40%
#
# Label/class Dress was miss labeled/classified 100 times
# So approximately 7.91% of the misslabels were for Dress
# the accuracy rate for the Dress alone was 90.00%
#
# Label/class Coat was miss labeled/classified 215 times
# So approximately 17.01% of the misslabels were for Coat
# the accuracy rate for the Coat alone was 78.50%
#
# Label/class Sandal was miss labeled/classified 40 times
# So approximately 3.16% of the misslabels were for Sandal
# the accuracy rate for the Sandal alone was 96.00%
#
# Label/class Shirt was miss labeled/classified 288 times
# So approximately 22.78% of the misslabels were for Shirt
# the accuracy rate for the Shirt alone was 71.20%
#
# Label/class Sneaker was miss labeled/classified 73 times
# So approximately 5.78% of the misslabels were for Sneaker
# the accuracy rate for the Sneaker alone was 92.70%
#
# Label/class Bag was miss labeled/classified 52 times
# So approximately 4.11% of the misslabels were for Bag
# the accuracy rate for the Bag alone was 94.80%
#
# Label/class Ankle boot was miss labeled/classified 20 times
# So approximately 1.58% of the misslabels were for Ankle boot
# the accuracy rate for the Ankle boot alone was 98.00%
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="1000">

# %%
mis_cls_stats(preds3, y_test)
# Out:
# The model gave 8827 correct and 1173 wrong predictions giving
# an accuracy rate of 0.8827 and an error rate of 0.1173
#
# Label/class T-shirt/top was miss labeled/classified 179 times
# So approximately 15.26% of the misslabels were for T-shirt/top
# the accuracy rate for the T-shirt/top alone was 82.10%
#
# Label/class Trouser was miss labeled/classified 15 times
# So approximately 1.28% of the misslabels were for Trouser
# the accuracy rate for the Trouser alone was 98.50%
#
# Label/class Pullover was miss labeled/classified 200 times
# So approximately 17.05% of the misslabels were for Pullover
# the accuracy rate for the Pullover alone was 80.00%
#
# Label/class Dress was miss labeled/classified 124 times
# So approximately 10.57% of the misslabels were for Dress
# the accuracy rate for the Dress alone was 87.60%
#
# Label/class Coat was miss labeled/classified 267 times
# So approximately 22.76% of the misslabels were for Coat
# the accuracy rate for the Coat alone was 73.30%
#
# Label/class Sandal was miss labeled/classified 52 times
# So approximately 4.43% of the misslabels were for Sandal
# the accuracy rate for the Sandal alone was 94.80%
#
# Label/class Shirt was miss labeled/classified 203 times
# So approximately 17.31% of the misslabels were for Shirt
# the accuracy rate for the Shirt alone was 79.70%
#
# Label/class Sneaker was miss labeled/classified 62 times
# So approximately 5.29% of the misslabels were for Sneaker
# the accuracy rate for the Sneaker alone was 93.80%
#
# Label/class Bag was miss labeled/classified 38 times
# So approximately 3.24% of the misslabels were for Bag
# the accuracy rate for the Bag alone was 96.20%
#
# Label/class Ankle boot was miss labeled/classified 33 times
# So approximately 2.81% of the misslabels were for Ankle boot
# the accuracy rate for the Ankle boot alone was 96.70%
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="1000">

# %%
mis_cls_stats(preds4, y_test)
# Out:
# The model gave 8795 correct and 1205 wrong predictions giving
# an accuracy rate of 0.8795 and an error rate of 0.1205
#
# Label/class T-shirt/top was miss labeled/classified 123 times
# So approximately 10.21% of the misslabels were for T-shirt/top
# the accuracy rate for the T-shirt/top alone was 87.70%
#
# Label/class Trouser was miss labeled/classified 6 times
# So approximately 0.50% of the misslabels were for Trouser
# the accuracy rate for the Trouser alone was 99.40%
#
# Label/class Pullover was miss labeled/classified 157 times
# So approximately 13.03% of the misslabels were for Pullover
# the accuracy rate for the Pullover alone was 84.30%
#
# Label/class Dress was miss labeled/classified 188 times
# So approximately 15.60% of the misslabels were for Dress
# the accuracy rate for the Dress alone was 81.20%
#
# Label/class Coat was miss labeled/classified 252 times
# So approximately 20.91% of the misslabels were for Coat
# the accuracy rate for the Coat alone was 74.80%
#
# Label/class Sandal was miss labeled/classified 19 times
# So approximately 1.58% of the misslabels were for Sandal
# the accuracy rate for the Sandal alone was 98.10%
#
# Label/class Shirt was miss labeled/classified 286 times
# So approximately 23.73% of the misslabels were for Shirt
# the accuracy rate for the Shirt alone was 71.40%
#
# Label/class Sneaker was miss labeled/classified 109 times
# So approximately 9.05% of the misslabels were for Sneaker
# the accuracy rate for the Sneaker alone was 89.10%
#
# Label/class Bag was miss labeled/classified 32 times
# So approximately 2.66% of the misslabels were for Bag
# the accuracy rate for the Bag alone was 96.80%
#
# Label/class Ankle boot was miss labeled/classified 33 times
# So approximately 2.74% of the misslabels were for Ankle boot
# the accuracy rate for the Ankle boot alone was 96.70%
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="1000">

# %%
mis_cls_stats(preds5, y_test)
# Out:
# The model gave 8771 correct and 1229 wrong predictions giving
# an accuracy rate of 0.8771 and an error rate of 0.1229
#
# Label/class T-shirt/top was miss labeled/classified 163 times
# So approximately 13.26% of the misslabels were for T-shirt/top
# the accuracy rate for the T-shirt/top alone was 83.70%
#
# Label/class Trouser was miss labeled/classified 25 times
# So approximately 2.03% of the misslabels were for Trouser
# the accuracy rate for the Trouser alone was 97.50%
#
# Label/class Pullover was miss labeled/classified 242 times
# So approximately 19.69% of the misslabels were for Pullover
# the accuracy rate for the Pullover alone was 75.80%
#
# Label/class Dress was miss labeled/classified 167 times
# So approximately 13.59% of the misslabels were for Dress
# the accuracy rate for the Dress alone was 83.30%
#
# Label/class Coat was miss labeled/classified 260 times
# So approximately 21.16% of the misslabels were for Coat
# the accuracy rate for the Coat alone was 74.00%
#
# Label/class Sandal was miss labeled/classified 18 times
# So approximately 1.46% of the misslabels were for Sandal
# the accuracy rate for the Sandal alone was 98.20%
#
# Label/class Shirt was miss labeled/classified 168 times
# So approximately 13.67% of the misslabels were for Shirt
# the accuracy rate for the Shirt alone was 83.20%
#
# Label/class Sneaker was miss labeled/classified 51 times
# So approximately 4.15% of the misslabels were for Sneaker
# the accuracy rate for the Sneaker alone was 94.90%
#
# Label/class Bag was miss labeled/classified 55 times
# So approximately 4.48% of the misslabels were for Bag
# the accuracy rate for the Bag alone was 94.50%
#
# Label/class Ankle boot was miss labeled/classified 80 times
# So approximately 6.51% of the misslabels were for Ankle boot
# the accuracy rate for the Ankle boot alone was 92.00%
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="1000">

# %%
mis_cls_stats(preds6, y_test)
# Out:
# The model gave 8720 correct and 1280 wrong predictions giving
# an accuracy rate of 0.872 and an error rate of 0.128
#
# Label/class T-shirt/top was miss labeled/classified 207 times
# So approximately 16.17% of the misslabels were for T-shirt/top
# the accuracy rate for the T-shirt/top alone was 79.30%
#
# Label/class Trouser was miss labeled/classified 19 times
# So approximately 1.48% of the misslabels were for Trouser
# the accuracy rate for the Trouser alone was 98.10%
#
# Label/class Pullover was miss labeled/classified 135 times
# So approximately 10.55% of the misslabels were for Pullover
# the accuracy rate for the Pullover alone was 86.50%
#
# Label/class Dress was miss labeled/classified 143 times
# So approximately 11.17% of the misslabels were for Dress
# the accuracy rate for the Dress alone was 85.70%
#
# Label/class Coat was miss labeled/classified 161 times
# So approximately 12.58% of the misslabels were for Coat
# the accuracy rate for the Coat alone was 83.90%
#
# Label/class Sandal was miss labeled/classified 42 times
# So approximately 3.28% of the misslabels were for Sandal
# the accuracy rate for the Sandal alone was 95.80%
#
# Label/class Shirt was miss labeled/classified 434 times
# So approximately 33.91% of the misslabels were for Shirt
# the accuracy rate for the Shirt alone was 56.60%
#
# Label/class Sneaker was miss labeled/classified 68 times
# So approximately 5.31% of the misslabels were for Sneaker
# the accuracy rate for the Sneaker alone was 93.20%
#
# Label/class Bag was miss labeled/classified 38 times
# So approximately 2.97% of the misslabels were for Bag
# the accuracy rate for the Bag alone was 96.20%
#
# Label/class Ankle boot was miss labeled/classified 33 times
# So approximately 2.58% of the misslabels were for Ankle boot
# the accuracy rate for the Ankle boot alone was 96.70%
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Extra:
# A separate notebook takes the data saved above to create a plot of the training and validation accuracy from one epoch to the next but if you want to display it here and save it to the current working directory copy and past the following lines of python code into a code cell and run it.
# ```Python
# fig = plt.figure()
# plt.plot(np.arange(2,7), g_data[:, 0]*100, 'k.--', np.arange(2, 7), g_data[:, 1]*100, 'b.--', markersize=16)
# plt.xlabel('Num Layers', fontsize=16)
# plt.ylabel('% Accuracy', fontsize=16)
# plt.legend(['Train', 'Validation'], fontsize=16)
# plt.show()
# plt.savefig(fname='Vary_Num_Layers.png', format='png')
# ```
